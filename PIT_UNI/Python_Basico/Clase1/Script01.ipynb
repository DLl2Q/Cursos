# %% [markdown]
# # PIT426 : Programacion en Python Basico
#
# El curso consta de 6 sesiones, cuyo horario es los lunes, miercoles y viernes de 8 a 11 AM.
#
# El profesor encargado de desarrollar el curso es [**Abraham Zamudio**](https://www.linkedin.com/in/abraham-zamudio/)

# %% [markdown]
# ## Primera Clase (20/10/2025)
#
# Los tópicos que tenemos que desarrollar son :
# * Primeros pasos usando Google colaboratory
# * Desarrollo y evolución de los lenguajes de programación.
# * Introducción al lenguaje de programación [Python](https://www.python.org/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Bienvenidos al curso : PIT426 Programacion en Python Basico
# Fecha : 20/10/2025
# Abraham Zamudio
