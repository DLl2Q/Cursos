# %% [markdown]
# # PRIMEROS PASOS USANDO PYTHON
#   1. Definición y operaciones con variables numéricas
#   2. Definición y operaciones con variables de tipo cadena de caracter
#   3. Definición y operaciones con variables lógicas

# %%
# Definicion de variables
variable1 = 125
peso_en_el_año_2025 = 100
primer_nombre = "Abraham"
segundo_nombre = "Gerardo"
apellido_paterno = "Zamudio"
red_social_1 = "https://www.linkedin.com/in/abraham-zamudio/"
imc = 28.6
decision1 = True
decision2 = False
complejo1 = 12+24j
complejo2 = 2j +2.3

# %%
# Funcion type
type(variable1)
# Out:
# int

# %%
# funcion type
type(complejo2)
# Out:
# complex

# %%
# Tipo de dato
type(imc)
# Out:
# float

# %%
# Cambiemos el valor almacenado en una variable determinada : variable1
variable1 = "ciento veinticinco"
type(variable1)
# Out:
# str

# %%
# Para podere obtener informacion de una variable determinado, esta debe estar
# creada en memoria ram
type(solucion_EDP_Estocastica)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3178216784.py in <cell line: 0>()
# ----> 1 type(solucion_EDP_Estocastica)
#
# NameError: name 'solucion_EDP_Estocastica' is not defined

# %% [markdown]
# # Operaciones de naturaleza numerica

# %%
# Definamos otras variables de naturaleza numerica
x1 = 159.56
x2 = -125.123
x3 = 12

# %%
# Cuanto tenemos informacion de naturaleza numerica , es de esperar
# que se tenga disponibles las operaciones aritmeticas basicas
# suma : +
# resta : -
# multiplicacion : *
# division : /

x4 = x3 + x1
x5 = x4 - x2
x6 = x5 * 0.002
x7 = 125/39

# %%
# Podemos utilizar parentesis para ordenar una operacion mas compleja
x8 = ((x4 + 3.15*x5)/(x7*3.5))- 3.14159

# %%
# Potenciacion : **
x9 = x8**(2.7)
x10 = (x1 + x2 +x3)**(1/(x6))

# %%
# Observar el valor de una unica variable
x10
# Out:
# 644.4169387323019

# %%
x11 = 256**(1/x10) + x8
x11
# Out:
# 96.4689870534178

# %%
# Division entera
# Algoritmo de Euclides : D = d * q +r
# D : Dividendo
# d = dividor
# q = cociente
# r = residuo

D = 2025
d = 43
q = D // d
r = D % d

# %%
q
# Out:
# 47

# %%
r
# Out:
# 4

# %%
# Division de D y d
D/d
# Out:
# 47.093023255813954

# %% [markdown]
# ## El modulo `math`

# %%
# Carguemos el modulo
import math as m

# %%
# Documentacion del modulo
help(m)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
# Funcion dir : Lista los elementos que provee el modulo math
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# # Lista de elementos de interes del modulo math
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp'

# %%
# Documentacion de la funcion sin
help(m.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
# Calculemos el seno de 30°
m.sin(30*m.pi/180)

# Todo calculo numerico/aritmetico en una computadora (en un sistema digital)
# es meramente una aproximacion
# Out:
# 0.49999999999999994

# %%
# Documentacion de la funcion tan del modulo math (alias m)
help(m.tan)
# Out:
# Help on built-in function tan in module math:
#
# tan(x, /)
#     Return the tangent of x (measured in radians).

# %%
# Calculemos la tangente de 45°
m.tan(45*m.pi/180)

# Todo calculo numerico/aritmetico en una computadora (en un sistema digital)
# es meramente una aproximacion
# Out:
# 0.9999999999999999

# %%
# Documentacion de la funcion radians
help(m.radians)
# Out:
# Help on built-in function radians in module math:
#
# radians(x, /)
#     Convert angle x from degrees to radians.

# %%
# Utilicemos las funciones radians y tan para el calculo de la tangente de 45°
m.tan(m.radians(45))
# Out:
# 0.9999999999999999

# %% [markdown]
# **tareita** : Aprender a utilizar todas los elementos de interes del modulo math

# %% [markdown]
# ## El modulo `random`

# %%
# Carguemos el modulo random
import random as rnd

# %%
# Documentacion del modulo random (alias rnd)
help(rnd)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
# Lista de elementos que componen al modulo random : Funcion dir
dir(rnd)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# # Lista de elementos de interes del modulo random
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate'

# %%
# Documentacion de la funcion gauss del modulo random
help(rnd.gauss)
# Out:
# Help on method gauss in module random:
#
# gauss(mu=0.0, sigma=1.0) method of random.Random instance
#     Gaussian distribution.
#
#     mu is the mean, and sigma is the standard deviation.  This is
#     slightly faster than the normalvariate() function.
#
#     Not thread-safe without a lock around calls.

# %%
g1 = rnd.gauss()
g1
# Out:
# -1.079239419567036

# %%
g2 = rnd.gauss(9.81, m.pi)
g2
# Out:
# 11.617845860229632

# %% [markdown]
# **tareita** Aprender a utilizar a todos los elementos de interes del modulo randon.

# %% [markdown]
# # Las variables de tipo cadena de caracter

# %%
# Definicion
cad1 = "PIT416 : Programacion Python Basico"
cad2 = 'Segunda clase : 22/10/2025'
cad3 = """UNIVERSIDAD NACIONAL DE INGENIERIA"""

# %%
# tipo de dato
type(cad1)
# Out:
# str

# %%
# tipo de dato
type(cad2)
# Out:
# str

# %%
# tipo de dato
type(cad3)
# Out:
# str

# %% [markdown]
# ## Dos Operaciones fundamentales : concatenacion - repeticion

# %%
# + : concatenar variables de tipo str
cad4 = cad1 + " -> " +  cad2
cad4
# Out:
# 'PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025'

# %%
#  * : Repetir
cad5 = 5 * cad4
cad6 = cad1 * 2025

# %%
cad5
# Out:
# 'PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025PIT416 : Programacion Python Basico -> Segunda clase : 22/10/2025'

# %%
cad6
# Out:
# 'PIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programacion Python BasicoPIT416 : Programa
# ...

# %%
cad7 = 20*cad6 + cad5*25
type(cad7)
# Out:
# str

# %% [markdown]
# ## Las variables str son objetos indexables

# %%
# Podemos acceder a sus elementos por intermedio de indices
# En python, los indices inician en cero

# %%
# Primera componente de cad7
cad7[0]
# Out:
# 'P'

# %%
# Quinto elemento de cad7
cad7[4]
# Out:
# '1'

# %%
# PAra acceder a los ultimos elementos utilizamos indices negativas que
# inician en -1 y van disminuyendo de -1 en -1

# %%
# Ultima componente de cad7
cad7[-1]
# Out:
# '5'

# %%
# penultima componente de cad7
cad7[-2]
# Out:
# '2'

# %%
# Notacion slice
# Acceso a las primeras 8 componentes de cad7
cad8 = cad7[:7+1]
cad8
# Out:
# 'PIT416 :'

# %%
# Ultimas 15 componentes de cad7
cad9 = cad7[-15:]
cad9
# Out:
# 'se : 22/10/2025'

# %% [markdown]
# ## Contar el numero de elementos de una variable de tipo str

# %%
# Funcion len
len(cad9)
# Out:
# 15

# %%
# Funcion len
len(cad6)
# Out:
# 70875

# %% [markdown]
# ## Metodos que se puede aplicar a una variable de tipo str

# %%
# Funcion dir
dir(cad1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# # Los metodos de interes que se puede aplicar a una variable de tipo str
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill'

# %%
# Documentacion del metodo capitalize
help("".capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
# Creacion de una nueva variable de tipo cadena de caracter
cad10 = "esta es la peor clase de mi vida"

# %%
cad10.capitalize()
# Out:
# 'Esta es la peor clase de mi vida'

# %%
# Documentacion del metodo upper
help(cad10.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
cad10.upper()
# Out:
# 'ESTA ES LA PEOR CLASE DE MI VIDA'

# %%
# Notar que la aplicacion de metodos (como por ejemplo : capitalize , upper) no
# modifica la variable original.
cad10
# Out:
# 'esta es la peor clase de mi vida'

# %% [markdown]
# **Tareita** Aprender que es lo que hace cada metodo de interes de una variable de tipo cadena de caracter

# %% [markdown]
# # El modulo `string`

# %%
# Carguemos el modulo string
import string

# %%
# Documentacion del modulo string
help(string)
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/string.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...

# %%
signos_puntuacion = string.punctuation
signos_puntuacion
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
abcdario = string.ascii_letters
abcdario
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# tipo de dato
type(signos_puntuacion)
# Out:
# str

# %%
# tipo de dato
type(abcdario)
# Out:
# str

# %% [markdown]
# # Variables de tipo `bool`

# %%
# Definicion
b1 = True
b2 = False

# %%
# tipo de dato
type(b1)
# Out:
# bool

# %%
# tipo de dato
type(b2)
# Out:
# bool

# %%
# Definamos variables bool  utilizando operaciones de comparacion entre
# variables numericas
b3 = 12 > 13
b4 = 0.12 >= 0.1**(-0.2)
b5 = 23 < 2.3*10.000001
b6 = 34 <= 34
b7 = 3.14159 == m.pi
b8 = 12.3 != (123/10)

# %%
# tipo de dato
type(b8)
# Out:
# bool

# %% [markdown]
# ## Operaciones con datos de tipo bool

# %%
# and : y logico
# or : o logico
# not : negacion

# %%
b9 = b1 and b8
b9
# Out:
# False

# %%
b10 = b7 or b2
b10
# Out:
# False

# %%
b11 = not b10
b11
# Out:
# True

# %%
b12 = ((not b1) and (b2 or b3)) or (not b11)
b12
# Out:
# False
